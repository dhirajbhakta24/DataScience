# %%
print("Today we will learn about list and start git ")
# Out:
# Today we will learn about list and start git

# %%
l = [10,1.2,"Hello","DHiraj",1230]
print(l[4])
print(l[-1]) #gives the last element of the list
# Out:
# 1230
# 1230

# %%
print(len(l)) #len()-> gives the length of the list
# Out:
# 5

# %%
l.append("alpha") #appends element at the end of the list
print(l)
